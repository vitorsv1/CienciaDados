# %% [markdown]
# ___
# # Ciência dos Dados - PROJETO 1

# %% [markdown]
# ## Vitor Satyro Vitturi
# ___

# %% [markdown]
# ## TÍTULO DO SEU PROJETO

# %% [markdown]
# ___
# ## Introdução
#
# Descreva aqui o que pretende analisar!
#
# Capriche no português!!
# Se quiser pode utilizar pesquisas semelhantes publicadas em sites confiáveis!!

# %% [markdown]
# ___
# ## Análise e Resultados

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\vitor\Dropbox\Insper\2017.2\Ciencia de Dados\Projeto1\CienciaDados

# %%
#Se usar o arquivo descompactado
dados_2015 = pd.read_csv('DOM2015.csv',sep=',')

dados_2015 = pd.DataFrame(dados_2015)

dados_2015_lido = dados_2015.loc[:,['UF','V02322','V0210', 'V4105', 'V0232']]

dados_2015_sem_nulo = dados_2015_lido.loc[pd.notnull(dados_2015_lido.UF) & \
                                          pd.notnull(dados_2015_lido.V0232) & \
                                          pd.notnull(dados_2015_lido.V0210) & \
                                          pd.notnull(dados_2015_lido.V4105) & \
                                          pd.notnull(dados_2015_lido.V02322)]

dados_15 = dados_2015_sem_nulo.loc[(dados_2015_sem_nulo.UF == 35) & \
                                   (dados_2015_sem_nulo.V02322 == 2) & \
                                   (dados_2015_sem_nulo.V0210 == 2) & \
                                   (dados_2015_sem_nulo.V4105 == 1)]

dados_15.loc[:,"UF"] = dados_15.UF.astype('category')
#dados_15.V0232 = dados_15.V0232.astype('category')
#dados_15.V0210 = dados_15.V0210.astype('category')
#dados_15.V4105 = dados_15.V4105.astype('category')
#dados_15.V02322 = dados_15.V02322.astype('category')

dados_15 = dados_15.rename(columns = {'V02322':'Acesso Internet', 'V0210':'Terreno Próprio', 'V4105':'Região de Moradia'})

dados_15.UF.cat.categories = {'São Paulo'}

dados_15
#dados_2015_sem_nulo.to_csv('dados_2015_filtrado.csv')
# Out:
# C:\Users\vitor\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#         UF  Acesso Internet  Terreno Próprio  Região de Moradia  V0232  \
# 93132   35              2.0              2.0                  1    2.0
# 93133   35              2.0              2.0                  1    2.0
# 93140   35              2.0              2.0                  1    2.0
# 93147   35              2.0              2.0                  1    2.0
# 93148   35              2.0              2.0                  1    2.0
# 93149   35              2.0              2.0                  1    2.0
# 93150   35              2.0              2.0                  1    2.0
# 93157   35              2.0              2.0                  1    2.0
# 93160   35              2.0              2.0                  1    2.0
# 93167   35              2.0              2.0                  1    2.0
# 93171   35              2.0              2.0                  1    2.0
# 93172   35              2.0              2.0                  1    2.0
# 93173   35              2.0              2.0                  1    2.0
# 93177   35              2.0              2.0                  1    4.0
# 93179   35              2.0              2.0                  1    2.0
# 93184   35              2.0              2.0                  1    2.0
# 93186   35              2.0              2.0                  1    2.0
# 93187   35              2.0              2.0                  1    2.0
# 93193   35              2.0              2.0                  1    2.0
# 93195   35              2.0              2.0                  1    4.0
# 93196   35              2.0              2.0                  1    2.0
# 93198   35              2.0              2.0                  1    2.0
# 93201   35              2.0              2.0                  1    2.0
# 93204   35              2.0              2.0                  1    2.0
# 93205   35              2.0              2.0                  1    2.0
# 93210   35              2.0              2.0                  1    2.0
# 93211   35              2.0              2.0                  1    4.0
# 93213   35              2.0              2.0                  1    2.0
# 93219   35              2.0              2.0                  1    2.0
# 93222   35              2.0              2.0                  1    2.0
# ...     ..              ...              ...                ...    ...
# 110315  35              2.0              2.0                  1    2.0
# 110317  35              2.0              2.0                  1    2.0
# 110322  35              2.0              2.0                  1    2.0
# 110326  35              2.0              2.0                  1    2.0
# 110327  35              2.0              2.0                  1    2.0
# 110335  35              2.0              2.0                  1    2.0
# 110338  35              2.0              2.0                  1    2.0
# 110341  35              2.0              2.0                  1    2.0
# 110347  35              2.0              2.0                  1    2.0
# 110355  35              2.0              2.0                  1    2.0
# 110356  35              2.0              2.0                  1    2.0
# 110359  35              2.0              2.0                  1    2.0
# 110362  35              2.0              2.0                  1    2.0
# 110364  35              2.0              2.0                  1    2.0
# 110365  35              2.0              2.0                  1    2.0
# 110369  35              2.0              2.0                  1    4.0
# 110400  35              2.0              2.0                  1    2.0
# 110401  35              2.0              2.0                  1    2.0
# 110403  35              2.0              2.0                  1    2.0
# 110404  35              2.0              2.0                  1    2.0
# 110405  35              2.0              2.0                  1    2.0
# 110408  35              2.0              2.0                  1    2.0
# 110409  35              2.0              2.0                  1    2.0
# 110410  35              2.0              2.0                  1    2.0
# 110411  35              2.0              2.0                  1    2.0
# 110412  35              2.0              2.0                  1    2.0
# 110416  35              2.0              2.0                  1    2.0
# 110418  35              2.0              2.0                  1    2.0
# 110420  35              2.0              2.0                  1    2.0
# 110421  35              2.0              2.0                  1    2.0
#
#               UF2
# 93132   São Paulo
# 93133   São Paulo
# 93140   São Paulo
# 93147   São Paulo
# 93148   São Paulo
# 93149   São Paulo
# 93150   São Paulo
# 93157   São Paulo
# 93160   São Paulo
# 93167   São Paulo
# 93171   São Paulo
# 93172   São Paulo
# 93173   São Paulo
# 93177   São Paulo
# 93179   São Paulo
# 93184   São Paulo
# 93186   São Paulo
# 93187   São Paulo
# 93193   São Paulo
# 93195   São Paulo
# 93196   São Paulo
# 93198   São Paulo
# 93201   São Paulo
# 93204   São Paulo
# 93205   São Paulo
# 93210   São Paulo
# 93211   São Paulo
# 93213   São Paulo
# 93219   São Paulo
# 93222   São Paulo
# ...           ...
# 110315  São Paulo
# 110317  São Paulo
# 110322  São Paulo
# 110326  São Paulo
# 110327  São Paulo
# 110335  São Paulo
# 110338  São Paulo
# 110341  São Paulo
# 110347  São Paulo
# 110355  São Paulo
# 110356  São Paulo
# 110359  São Paulo
# 110362  São Paulo
# 110364  São Paulo
# 110365  São Paulo
# 110369  São Paulo
# 110400  São Paulo
# 110401  São Paulo
# 110403  São Paulo
# 110404  São Paulo
# 110405  São Paulo
# 110408  São Paulo
# 110409  São Paulo
# 110410  São Paulo
# 110411  São Paulo
# 110412  São Paulo
# 110416  São Paulo
# 110418  São Paulo
# 110420  São Paulo
# 110421  São Paulo
#
# [5438 rows x 6 columns]

# %%
dados_2014 = pd.read_csv('DOM2014.csv',sep=',')
dados_2014 = pd.DataFrame(dados_2014)
dados_2014_lido = dados_2014.loc[:,['UF','V02322','V0210', 'V4105', 'V0232']]
dados_2014_sem_nulo = dados_2014_lido[pd.notnull(dados_2014_lido.UF) & \
                                      pd.notnull(dados_2014_lido.V0232) & \
                                      pd.notnull(dados_2014_lido.V0210) & \
                                      pd.notnull(dados_2014_lido.V4105) & \
                                      pd.notnull(dados_2014_lido.V02322)]
dados_2014_sem_nulo.to_csv('dados_2014_filtrado.csv')

# %%
dados_2013 = pd.read_csv('DOM2013.csv',sep=',')
dados_2013 = pd.DataFrame(dados_2013)
dados_2013_lido = dados_2015.loc[:,['UF','V02322','V0210', 'V4105', 'V0232']]
dados_2013_sem_nulo = dados_2015_lido[pd.notnull(dados_2013_lido.UF) & \
                                      pd.notnull(dados_2013_lido.V0232) & \
                                      pd.notnull(dados_2013_lido.V0210) & \
                                      pd.notnull(dados_2013_lido.V4105) & \
                                      pd.notnull(dados_2013_lido.V02322)]
dados_2013_sem_nulo.to_csv('dados_2013_filtrado.csv')

# %% [markdown]
# ___
# ## Conclusão

# %% [markdown]
# Descreva aqui suas conclusões!
